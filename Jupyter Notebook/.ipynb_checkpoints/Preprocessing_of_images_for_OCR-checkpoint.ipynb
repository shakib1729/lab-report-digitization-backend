# %%
# !pip install pillow
# !pip install opencv-python
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (6.2.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python) (1.17.5)

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.6/dist-packages (0.3.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from pytesseract) (6.2.2)

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-489432c0-9dff-4ddf-bd89-6b1bf930f3b4" name="files[]" multiple disabled />
#      <output id="result-489432c0-9dff-4ddf-bd89-6b1bf930f3b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving trail1.jpg to trail1.jpg

# %%
img=cv2.imread('trail1.jpg')
print(img.shape)
plt.imshow(img);
plt.show()
# Out:
# (4608, 3456, 3)

# %%
extractedInformation = pytesseract.image_to_string(img)
print(extractedInformation)
# Out:
# ~ CGHS-559490 MR.INTSAR AHMED Collected d
# Received
#
# 145073055 Age: 44 Years Gender: Male Reported
#
# Status : P Ref By: C.M.0.,CGHS DISPENSARY Report Status
# a i
#
# Test Name Results
#
#
#
#
#
# COMPLETE BLOOD COUNT (CBC)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (Electrical Impedance & VCS,Photometry ) ee
# panne SE a 43.00 - 17.00
# Hemoglobin 15.10 GigE __ ae
#
# 9 40.00 - 50.00
#
# Packed Cell Volume (PCV) 44.80 [% re a ae
#
# Ai lal |
# ; z
#
# RBC Count _ 5.11 mill/mms3 _ | 450-57 ——
# MCV 87.60 fl 80.00 - 100.00
#
# MCH 29.60 a pg — 27.00 - 32.00
#
# MCHC 33.80 | g/dL 32.00 - 35.00
# _ Red Cell Distribution Width (RDW) 14.30 be WO 11.50 - 14.50
# Total Leukocyte Count (EG) a SD ee thou/mm3 ___| 4.00 - 10.00
#
# Differential Leucocyte Count (DLC)
#
# Segmented Neutrophils 43.00 %o 40.00 - 80.00
# Lymphocytes 40.90 | % 20.00 - 40.00
# Monocytes | 8.80 % 2.00 - 10.00
# Eosinophils | 7.10 % 1.00 - 6.00
# Basophils 0.20 | % <2.00
# Absolute Leucocyte Count |
# Neutrophils 3.01 | thou/mm3 2.00 - 7.00
#
# Lymphocytes 2.86 | thou/mm3 1.00 - 3.00
# Monocytes 0.62 _thou/mms3 0.20 - 1.00
# i E . . |
# seen 0.50 thou/mm3 0.02 - 0.50
# _ Basophi |
# | anil a baa 0.01 thou/mm3 0.01 -0.10
# _ Platelet Co ae | eee i
# ee es — 80.0 _thou/mm3 150.00 - 450.00
#
#
#
# D CRRCHD DURRED: BELAR ORE MRLAGL Geamlan fue rarer 2cccd Ob kvbume moceeee ce

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img);
plt.show()

# %%
extractedInformation = pytesseract.image_to_string(img)
print(extractedInformation)
# Out:
# Hemoglobin
# SLS Method
#
# Hematocrit
# RBC Pulse Height Detection
#
# RBC Count
# HOF impedence
# MCV
# Calculated
# MCH
# Cilevlated
# MCHC
# Coleuated
# RDW (CV)
# Caleulated (Reportedas CV)
# Platelet Count
# HOF Impedance
# Total Leukocyte Count (TLC)
# How Cytometery
# Differential Count
# Neutrophils
# ‘Microscopie
# Lymphocytes
# ‘Meroscopic
#
# 12.54
#
# 39"
#
# 4.204
#
# 93
#
# 13.0
#
# 150
#
# 61
#
# a/dl
# %
#
# x10*6/ul
#
# fil
#
# Po
#
# g/dl
#
# %
# x10%3/ul
#
# x10*3/ul
#
# 13.0 - 17.0
#
# 42.0 - 50.0
#
# 45-55
#
# 83.0 - 101.0
# 27.0 - 32.0
# 31.5 - 34.5
# 12.0 - 15.0
# 150.0 - 450.0
#
# 4.0- 11.0
#
# 20.0 - 40.0

# %%
kernel = np.ones((1, 1), np.uint8)
img = cv2.dilate(img, kernel, iterations=1)
img = cv2.erode(img, kernel, iterations=1)
plt.imshow(img);
plt.show()

# %%
extractedInformation = pytesseract.image_to_string(img)
print(extractedInformation)
# Out:
# Hemoglobin
# SLS Method
#
# Hematocrit
# RBC Pulse Height Detection
#
# RBC Count
# HOF impedence
# MCV
# Calculated
# MCH
# Cilevlated
# MCHC
# Coleuated
# RDW (CV)
# Caleulated (Reportedas CV)
# Platelet Count
# HOF Impedance
# Total Leukocyte Count (TLC)
# How Cytometery
# Differential Count
# Neutrophils
# ‘Microscopie
# Lymphocytes
# ‘Meroscopic
#
# 12.54
#
# 39"
#
# 4.204
#
# 93
#
# 13.0
#
# 150
#
# 61
#
# a/dl
# %
#
# x10*6/ul
#
# fil
#
# Po
#
# g/dl
#
# %
# x10%3/ul
#
# x10*3/ul
#
# 13.0 - 17.0
#
# 42.0 - 50.0
#
# 45-55
#
# 83.0 - 101.0
# 27.0 - 32.0
# 31.5 - 34.5
# 12.0 - 15.0
# 150.0 - 450.0
#
# 4.0- 11.0
#
# 20.0 - 40.0

# %%
img = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
plt.imshow(img);
plt.show()

# %%
extractedInformation = pytesseract.image_to_string(img)
print(extractedInformation)
# Out:
# Hemoglobin
# od SMethot
#
# femnatocrit
# HAC Pulse taght Detection
#
# RBC Count
# HOP agence
# MCV
# Cokvister
# MCH
# Cloutier
# MCHC
# Chkeudarer
# RDW (CV)
# Caleulsted (Reported as OV}
# Ptatetet Count
# NDF Impedence
# Total Leukocyte Count (TLC)
# Flow Cytomatery
# Differential Count
# Neutrophils.
# eroscapt
# Lymphocytes
# ‘Microscopic
#
# 1250
#
# 390
#
# 4.209
#
# 93
#
# 13.0
#
# 1530
#
# 61
#
# g/dl
# %
#
# x10*6/ul
#
# fl
#
# Po
#
# gfdi
#
# %
# ¥1043/ul
#
# x1043/ul
#
# 13.0-17.0
#
# 42.0 - $0.0
#
# 45-55
#
# 83.0 - 101.0
# 27.0 - 32.0
# 31.5 - 34.5
# 12.0 - 15.0
# 150.0 - 450.0
#
# 4.0- 11.0
#
# 20.0 - 40.0
